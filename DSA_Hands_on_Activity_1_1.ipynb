# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristanSanchez/DSA-CpE-010-CpE21S4/blob/main/DSA_Hands_on_Activity_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 2: (Finite Algorithm)

# %% [markdown]
# The new list of numbers is given as 26, 49, 498, 9387, 48962, 1, -1. The value –1 is a unique number since all other numbers are positive. This means that the procedure will stop once -1 is encountered.
#
#
#
# Start
#
# Sum=0
#
# Get a value
#
# If the value = -1, go to step 7
#
# Add to sum (sum = sum + value)
#
# Go to step 3 to get the next value
#
# Output the sum
#
# Stop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 1: (Infinite Algorithm)

# %% [markdown]
# The problem with this algorithm is that, some of the steps appear more than once, i.e. step 5 get second number, step 7, get third number, etc. One could shorten the algorithm or flowchart as follows:
#
#
#
# Start
#
# Sum=0
#
# Get a value
#
# Sum = sum + value
#
# Go to step 3 to get the next value
#
# Output the sum
#
# Stop

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# # ADDITIONAL ACTIVITIES

# %% [markdown]
# 1. Design an algorithm and the corresponding flowchart for finding the sum of the numbers 2, 4, 6, 8, …, n (output: Algorithm and Flowchart)

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
#  2. Start
#  Initialize Sum to 0
#
#  Initialize n to 2
#
#  Get the value of n (Input)
#
#  Repeat Add n to Sum Increment n by 2
#
#  Get the value of n (Input)
#
#  Until n is greater than or equal to the desired value
#
#   Output Sum
#
#   Stop

# %% [markdown]
#   3. Reading and Displaying the Sum of 100 Numbers Algorithm:
#
#   Start
#
#   Initialize Sum to 0
#
#     Get a number
#
#     Add the number to Sum
#
#     Repeat until 100 (if n = 100) proceed to (step 6)
#
#     Output
#
#      Stop

# %% [markdown]
# 4. Finding the Largest of Two Numbers Algorithm:
#
# Start
#
#  Get the first number
#
# Get the second number
#
# If the first number is greater than the second number, then Output the first number
#
#  Else Output the second number
#
# stop

# %% [markdown]
# 5. Finding the Smallest of Two Numbers Algorithm:
# Start
#
# Get the first number
#
# Get the second number
#
# If the first number is smaller than the second number, then Output the first number
#
# Else Output the second number
#
# Stop

# %% [markdown]
# 6. Finding the Largest of Three Numbers Algorithm:
# Start
#
# Get the first number
#
# Get the second number
#
# Get the third number
#
# If the first number is greater than or equal to the second and third numbers, then Output the first number
#
# Else If the second number is greater than or equal to the third number,
# then Output the second number
#
# Else Output the third number
#
#  Stop

# %% [markdown]
#  7. Finding the Largest of 100 Numbers Algorithm:
#
#   Start
#
#   Initialize max with the smallest possible value
#
#    Repeat 100 times
#
#    Get a number
#
#     If the number is greater than max, then Set max to the number
#
#     End
#
#     output max
#
#     stop
